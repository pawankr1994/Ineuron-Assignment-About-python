# %% [markdown]
# #### Question 9 -
# Write a program to read the data from the following link, perform data analysis and answer the following questions
#
# Note -
#
# 1. Write code comments wherever required for code understanding
#
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
#
# Insights to be drawn -
#
# ● Get all the cars and their types that do not qualify for clean alternative fuel vehicle
#
# ● Get all TESLA cars with the model year, and model type made in Bothell City.
#
# ● Get all the cars that have an electric range of more than 100, and were made after
# 2015
#
# ● Draw plots to show the distribution between city and electric vehicle type

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
data_url = "https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(data_url)

# %%
df.sample(5)
# Out:
#         VIN (1-10)       County           City State  Postal Code  Model Year  \
# 60989   WBA8E1C59J         King     North Bend    WA      98045.0        2018
# 112266  KNDJX3AE4G      Whatcom     Bellingham    WA      98225.0        2016
# 112718  1C4JJXR63N  Walla Walla  College Place    WA      99324.0        2022
# 99366   7SAYGAEE6P     Franklin          Pasco    WA      99301.0        2023
# 75496   WMW13DJ01N    Jefferson  Port Townsend    WA      98368.0        2022
#
#          Make     Model                   Electric Vehicle Type  \
# 60989     BMW      330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 112266    KIA      SOUL          Battery Electric Vehicle (BEV)
# 112718   JEEP  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 99366   TESLA   MODEL Y          Battery Electric Vehicle (BEV)
# 75496    MINI   HARDTOP          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
# Get all the cars and their types that do not qualify for clean alternative fuel vehicle
df.loc[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].str.lower() == 'not eligible due to low battery range', ['Make', 'Model']]
# Out:
#           Make        Model
# 6         FORD       FUSION
# 7         AUDI         Q5 E
# 8         FORD        C-MAX
# 14        FORD        C-MAX
# 15         KIA         NIRO
# ...        ...          ...
# 130377     BMW         530E
# 130385    AUDI           A3
# 130390    JEEP     WRANGLER
# 130407  TOYOTA  PRIUS PRIME
# 130437     BMW         530E
#
# [16446 rows x 2 columns]

# %%
# Get all TESLA cars with the model year, and model type made in Bothell City
df.loc[(df['Make'] == 'TESLA') & (df['City'] == 'Bothell'), ['Model Year', 'Model']]
# Out:
#         Model Year    Model
# 39            2020  MODEL 3
# 217           2022  MODEL 3
# 218           2022  MODEL Y
# 222           2018  MODEL 3
# 292           2017  MODEL X
# ...            ...      ...
# 129778        2019  MODEL 3
# 129954        2021  MODEL 3
# 129976        2014  MODEL S
# 130295        2022  MODEL 3
# 130392        2018  MODEL 3
#
# [2407 rows x 2 columns]

# %%
df[(df['Make'] == 'TESLA') & (df['City'] == 'Bothell')]
# Out:
#         VIN (1-10)     County     City State  Postal Code  Model Year   Make  \
# 39      5YJ3E1EA6L  Snohomish  Bothell    WA      98012.0        2020  TESLA
# 217     5YJ3E1EB9N       King  Bothell    WA      98011.0        2022  TESLA
# 218     7SAYGDEEXN  Snohomish  Bothell    WA      98012.0        2022  TESLA
# 222     5YJ3E1EB6J       King  Bothell    WA      98011.0        2018  TESLA
# 292     5YJXCBE40H       King  Bothell    WA      98011.0        2017  TESLA
# ...            ...        ...      ...   ...          ...         ...    ...
# 129778  5YJ3E1EB3K  Snohomish  Bothell    WA      98012.0        2019  TESLA
# 129954  5YJ3E1EB3M  Snohomish  Bothell    WA      98021.0        2021  TESLA
# 129976  5YJSA1S10E  Snohomish  Bothell    WA      98021.0        2014  TESLA
# 130295  5YJ3E1EA8N  Snohomish  Bothell    WA      98021.0        2022  TESLA
# 130392  5YJ3E1EA9J       King  Bothell    WA      98011.0        2018  TESLA
#
# ...

# %%
# Get all the cars that have an electric range of more than 100 and were made after 2015

df.loc[(df['Electric Range'] > 100) & (df['Model Year'] > 2015), :]
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %%
# Draw plots to show the distribution between city and electric vehicle type

plt.figure(figsize=(12, 8))
grouped_data = df.groupby(['City', 'Electric Vehicle Type']).size().unstack()
grouped_data.plot(kind='bar', stacked=True)
plt.xlabel('City')
plt.ylabel('Count')
plt.title('Distribution of Electric Vehicle Types by City')
plt.legend(title='Electric Vehicle Type')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
